# %% [markdown]
# # Pre-Processing Dataset
#
# Here I generate the `galaxy_file1` which cointains the columns needed to this study: `Mr, R, R/R200, v_los, v_circ`.

# %%
from file_loc import FileLocs

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io.fits import getdata
import astropy.table as Table
import astropy.io.ascii as at

# %% [markdown]
# # Reading Initial Data

# %%
fl = FileLocs()
galaxy_file = fl.gal_fname0
cluster_file= fl.cls_fname

# %%
print('--------Initial Files-------')
print('Cluster File : %s'%cluster_file)
print('Galaxy File : %s'%galaxy_file)
print()
# Out:
# --------Initial Files-------
# Cluster File : ../data/groupCatalog_Yang_deCarvalho2017.csv
# Galaxy File : ../data/groupCatalog_Yang_deCarvalho2017_galaxy.csv

# %%
# load catalogs
cat = at.read(cluster_file)
gal0= at.read(galaxy_file)

# %%
cat
# Out:
# <Table length=319>
#  Yang    RA      DEC      z    logM200   R200   N200
# int64 float64  float64 float64 float64 float64 int64
# ----- -------- ------- ------- ------- ------- -----
#     2 240.5602 16.1113   0.036   15.29    2.01   525
#     4 247.1149 40.8317    0.03   14.66    1.24   217
#     5 247.1633 39.4674    0.03   14.81     1.4   277
#     6 167.6936 28.5374   0.033    14.6    1.18   167
#     7 351.1194 14.6251   0.042   14.51     1.1   106
#     8 239.5372 27.3133    0.09    15.1    1.71   183
#     9 241.5673 18.1483   0.038   14.48    1.08   143
#    10 223.2712  16.724   0.045   14.22    0.89   106
#    11  10.4693 -9.3997   0.056   14.96    1.55   156
#    12   14.206  -0.746   0.044   14.54    1.13    95
#   ...      ...     ...     ...     ...     ...   ...
#   616 172.1451 26.8291   0.053   14.15    0.84    28
#   621 215.2345  17.666   0.051   14.21    0.87    35
#   624 129.0212 52.7156   0.044   14.16    0.85    20
# ...

# %%
gal0
# Out:
# <Table length=61459>
#  Yang        objid             specobjid      ...  age_fire_p84   score
# int64        int64               str20        ...    float64     float64
# ----- ------------------- ------------------- ... ------------- ---------
#     2 1237665530650034690                null ...         -99.0 0.9158974
#     2 1237665530650101452                null ...         -99.0 0.9120452
#     2 1237665530650230847                null ...         -99.0 0.9118443
#     2 1237665530650231112 2841934444107950080 ...  6228817000.0 0.9118443
#     2 1237665530650231189 2841935543619577856 ...  5729034000.0 0.9118443
#     2 1237665547827347728 2841891013398652928 ... 10976760000.0 0.8717796
#     2 1237665547827479001                null ...         -99.0 0.8908026
#     2 1237665566081483195 2838400888110868480 ...  6528688000.0 0.9467953
#     2 1237665566081548631 2838401437866682368 ...  5828991000.0 0.9464893
# ...

# %% [markdown]
# # Mask Data

# %%
mask = gal0['z']>0.
mask&= gal0['mass_fire']>0

Nsize = np.count_nonzero(mask)

print('Masking Galaxies with no redshift or mass estimations')
print('New Size: %i'%(Nsize))
print('fraction: %.2f'%(1.*Nsize/len(gal0)))
# Out:
# Masking Galaxies with no redshift or mass estimations
# New Size: 43538
# fraction: 0.71

# %%
gal = gal0[mask]

# %%
gal0 = 0

# %% [markdown]
# ## To Do List
#
# * mask galaxies with z>0, mass_fire>0.
# * compute new quantities: R_R200, Mr, delta_z, v_los, v_circ

# %% [markdown]
# Distance from the Center
# ---------------------------------------
#
# To have the phase space we need first to compute the distance from the center, $R/R_{200}$.

# %%
id1  = np.loadtxt('cluster_cid.npy').astype(int)
id0  = np.loadtxt('cluster_gid.npy').astype(int)
rnorm= np.loadtxt('cluster_radii.npy').astype(float)

# %%
plt.hist(rnorm)
# Out:
# (array([2604., 4611., 5427., 5895., 6555., 7210., 7801., 8270., 8415.,
#         5912.]),
#  array([6.99710471e-04, 2.20629690e-01, 4.40559670e-01, 6.60489650e-01,
#         8.80419630e-01, 1.10034961e+00, 1.32027959e+00, 1.54020957e+00,
#         1.76013955e+00, 1.98006953e+00, 2.19999951e+00]),
#  <BarContainer object of 10 artists>)

# %%
from astropy.cosmology import FlatLambdaCDM
from astropy import units as u
from astropy.constants import G

cosmo = FlatLambdaCDM(H0=70, Om0=0.283)
Msol = 1.98847e33
Mpc2cm = 3.086e+24
rad2deg= 180/np.pi
h=0.7

def AngularDistance(z):
    DA = float( (cosmo.luminosity_distance(z)/(1+z)**2)/u.Mpc ) # in Mpc
    return DA
AngularDistance = np.vectorize(AngularDistance)

#--- Critical universe density
def rhoc(z):
    try:
        rho_c = float(cosmo.critical_density(z)/(u.g/u.cm**3)) # in g/cm**3
    except:
        rho_c = [float(cosmo.critical_density(zi)/(u.g/u.cm**3)) for zi in z]
        rho_c = np.array(rho_c)
    
    rho_c = rho_c*(Mpc2cm**3)/Msol # in Msol/Mpc**3
    return rho_c

def vcirc(mass,redshift,mdef,cosmo):
    '''Calculate circular velocity in km/s for halos of mass M (Msun/h)'''
    rho_crit = cosmo.critical_density(redshift)
    if mdef[-1] == 'c':
        delta = int(mdef[:-1])
        rho = delta*rho_crit
    elif mdef[-1] == 'm':
        delta = int(mdef[:-1])
        rho = delta*rho_crit*cosmo.Om(redshift)
    else:
        raise RuntimeError("Not correct mass definition")
    v = np.sqrt(G*(np.pi*4*rho/3)**(1./3)*(mass*u.Msun/cosmo.h)**(2./3))
    a = v.to(u.km/u.s)
    return a.value

# %%
#DA = AngularDistance(zcls)

def convertDegreeToMpc(theta,z):
    da     = AngularDistance(z)
    length = (theta*np.pi/180)*da
    return length

def convertR200toM200(R200,z, nc=200):
    ## M200 in solar masses
    ## R200 in Mpc
    rho = rhoc(z)
    M200 = nc*4*np.pi*rho*R200**3/3
    return M200

# %%
r200_deg0= Cluster_data.R200C_DEG.to_numpy()#[id1]
z0       = Cluster_data.CLUZSPEC.to_numpy()#[id1]

r200     = convertDegreeToMpc(r200_deg0,z0)[id1]
zcls     = z0[id1]

# %%
vlos    = Galaxy_data.v_los.to_numpy()[id0]

# %%
m200 = convertR200toM200(r200,zcls)
vc   = vcirc(m200,zcls,'200c',cosmo)

vlosn = vlos/vc

# %%
cut = np.abs(vlosn)<=3

_ = plt.hist(vlosn,bins=np.linspace(-5.,5.,50))
_ = plt.hist(vlosn[cut],bins=np.linspace(-5.,5.,50))

# %%
import seaborn as sns
sns.set_context('notebook')

# %%
# ax = sns.jointplot(x=rnorm[cut], y=vlos[cut], kind="scatter", s=10, alpha=0.3, space=0)
# ax = sns.jointplot(x=rnorm[cut], y=vlos[cut], kind="resid", space=0, height=6, ratio=6, joint_kws = {'scatter_kws':dict(alpha=0.2,s=50)},ylim=(-1650,1650))
ax = sns.jointplot(x=rnorm[cut], y=vlosn[cut], kind="resid", space=0, height=6, ratio=6, joint_kws = {'scatter_kws':dict(alpha=0.2,s=50)})
ax.set_axis_labels(r'$R/R_{200}$', r'$v_{los}/v_{cir}$ ', fontsize=16)
ax.fig.set_figwidth(8)

# %% [markdown]
# ## Assign Orbital Classification

# %%
from sklearn.ensemble import RandomForestClassifier
import joblib
loaded_rf = joblib.load("../phase_space/classification_2d_rf.joblib")
# Out:
# /usr/local/anaconda/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /usr/local/anaconda/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.24.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
gal = pd.DataFrame ({ 'r2d':rnorm, 'vlos':vlosn})
tags = loaded_rf.predict(gal) 
#predicted tag: 0 = orbiting, 1 = infalling, 2 = background

# %%
tag_probability = loaded_rf.predict_proba(gal)

# %%
tag_probability
# Out:
# array([[0.95, 0.05, 0.  ],
#        [0.01, 0.  , 0.99],
#        [0.  , 0.  , 1.  ],
#        ...,
#        [0.  , 0.  , 1.  ],
#        [0.  , 0.56, 0.44],
#        [0.  , 0.52, 0.48]])

# %%
plt.figure(figsize=(8,4))
plt.scatter(rnorm[cut],vlosn[cut],c=tags[cut],alpha=0.3,s=20)
plt.xlabel(r'$R/R_{200}$',fontsize=16)
plt.ylabel(r'$v_{los}/ v_{circ} $',fontsize=16)
plt.colorbar()

# %%
infall = tags==1
orbit  = tags==0

# %%
_ = plt.hist(rnorm[infall],histtype='step',bins=30)
_ = plt.hist(rnorm[orbit],histtype='step' ,bins=30)

# %%
_ = plt.hist(vlos[infall],histtype='step')
_ = plt.hist(vlos[orbit],histtype='step')

# %%
path = '/Users/jesteves/Documents/repos/red-dragon-gamma'

import sys
sys.path.append(path)
import rd_gamma as redDragon

# %%
rd = redDragon.dragon('../data/out_2K_amag_20.8.h5',factor=-10.)
redDragon.plot_WMS(rd)

# %%
filters = ['g','r','i','z']

Z     = Galaxy_data.z.to_numpy()[id0]
bands = np.vstack([Galaxy_data['cModelMag_%s'%(bi)].to_numpy()[id0] - Galaxy_data['extinction_%s'%(bi)].to_numpy()[id0]  for bi in filters]).T

# %%
pred = rd.P_red(Z,bands).astype(float)
pred[np.isnan(pred)] = 0.

rmask= pred>0.5
# Out:
# /usr/local/anaconda/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/anaconda/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/anaconda/lib/python3.8/site-packages/numpy/linalg/linalg.py:2098: RuntimeWarning: invalid value encountered in slogdet
#   sign, logdet = _umath_linalg.slogdet(a, signature=signature)
# /Users/jesteves/Documents/repos/red-dragon-gamma/rd_gamma.py:452: RuntimeWarning: overflow encountered in exp
#   denominator = np.sum(np.exp(logLs),axis=0)
# /Users/jesteves/Documents/repos/red-dragon-gamma/rd_gamma.py:454: RuntimeWarning: overflow encountered in exp
#   return np.array([np.exp(logLs[ii])/denominator \
# /Users/jesteves/Documents/repos/red-dragon-gamma/rd_gamma.py:454: RuntimeWarning: invalid value encountered in true_divide
# ...

# %%
zcls = Galaxy_data.z.to_numpy()[id0]
zcut = zcls<0.3

# %%
rabs = Galaxy_data.rabs.to_numpy()[id0]
zcut = rabs<=-20.8

# %%
red_infall = rmask&infall&zcut&cut
red_orbit = rmask&orbit&zcut&cut

blue_infall = np.logical_not(rmask)&infall&zcut&cut
blue_orbit  = np.logical_not(rmask)&orbit&zcut&cut

# %%
np.count_nonzero(zcut&cut)
# Out:
# 8951

# %%
np.count_nonzero(red_infall)
# Out:
# 1468

# %%
np.count_nonzero(red_orbit)
# Out:
# 3454

# %%
np.count_nonzero(blue_infall)
# Out:
# 916

# %%
np.count_nonzero(blue_orbit)
# Out:
# 1676

# %%
plt.figure(figsize=(8,4))
plt.scatter(rnorm[red_orbit],vlosn[red_orbit],alpha=0.3,s=20)
plt.scatter(rnorm[blue_orbit],vlosn[blue_orbit],alpha=0.3,s=20)

plt.xlabel(r'$R/R_{200}$',fontsize=16)
plt.ylabel(r'$v_{los}/ v_{circ} $',fontsize=16)
plt.colorbar()

# %%
pb_infall = (1-pred)*tag_probability[:,1]
pr_infall = pred*tag_probability[:,1]

# %%
pb_tag = (1-pred)[:,np.newaxis]*tag_probability
pr_tag = pred[:,np.newaxis]*tag_probability

# %%
plt.figure(figsize=(8,4))
b = plt.hist(rnorm[zcut&cut] ,weights=pb_infall[zcut&cut],histtype='step',lw=5,bins=21)
r = plt.hist(rnorm[zcut&cut] ,weights=pr_infall[zcut&cut],histtype='step',lw=5,color='r',bins=b[1])

bmed = .5*(b[1][1:]+b[1][:-1])
plt.plot(bmed,100*b[0]/r[0])

plt.xlabel(r'$R/R_{200}$',fontsize=16)
plt.title('Infall Population')
# Out:
# Text(0.5, 1.0, 'Infall Population')

# %%
plt.figure(figsize=(8,4))
b = plt.hist(rnorm[zcut&cut] ,weights=pb_tag[:,0][zcut&cut],histtype='step',lw=5,bins=21)
r = plt.hist(rnorm[zcut&cut] ,weights=pr_tag[:,0][zcut&cut],histtype='step',lw=5,color='r',bins=b[1])

bmed = .5*(b[1][1:]+b[1][:-1])
plt.plot(bmed,100*b[0]/r[0])

plt.xlabel(r'$R/R_{200}$',fontsize=16)
plt.title('Orbital Population')
# Out:
# Text(0.5, 1.0, 'Orbital Population')

# %%
plt.figure(figsize=(8,4))
b = plt.hist(rnorm[zcut&cut] ,weights=pb_tag[:,2][zcut&cut],histtype='step',lw=5,bins=15)
r = plt.hist(rnorm[zcut&cut] ,weights=pr_tag[:,2][zcut&cut],histtype='step',lw=5,color='r',bins=b[1])

bmed = .5*(b[1][1:]+b[1][:-1])
plt.plot(bmed,100*b[0]/r[0])

plt.xlabel(r'$R/R_{200}$',fontsize=16)
plt.title('Interlopers Population')
# Out:
# Text(0.5, 1.0, 'Interlopers Population')

# %%
plt.figure(figsize=(8,4))
b = plt.hist(vlosn[zcut&cut] ,weights=pb_infall[zcut&cut],histtype='step',lw=5,bins=21)
r = plt.hist(vlosn[zcut&cut] ,weights=pr_infall[zcut&cut],histtype='step',lw=5,color='r',bins=b[1])

bmed = .5*(b[1][1:]+b[1][:-1])
plt.plot(bmed,100*b[0]/r[0])

plt.xlabel(r'$R/R_{200}$',fontsize=16)
plt.title('Infall Population')
# Out:
# Text(0.5, 1.0, 'Infall Population')

# %%
plt.figure(figsize=(8,4))
b = plt.hist(vlosn[zcut&cut] ,weights=pb_tag[:,0][zcut&cut],histtype='step',lw=5,bins=21)
r = plt.hist(vlosn[zcut&cut] ,weights=pr_tag[:,0][zcut&cut],histtype='step',lw=5,color='r',bins=b[1])

bmed = .5*(b[1][1:]+b[1][:-1])
plt.plot(bmed,100*b[0]/(r[0]+0.1))

plt.xlabel(r'$R/R_{200}$',fontsize=16)
plt.title('Orbital Population')
# Out:
# Text(0.5, 1.0, 'Orbital Population')

# %%
# https://bdiemer.bitbucket.io/colossus/halo_concentration.html
